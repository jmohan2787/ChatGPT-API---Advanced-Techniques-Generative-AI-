# %% [markdown]
# <a href="https://colab.research.google.com/github/jmohan2787/ChatGPT-API---Advanced-Techniques-Generative-AI-/blob/main/Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyAXao1jK1YW7FSMYFsoqYny6d7sNo5nygY")

model = genai.GenerativeModel('gemini-2.5-pro')
response = model.generate_content("Can you procedure to prepare Dosai?")
print(response.text)
# Out:
# Of course! Here is a detailed, step-by-step procedure to prepare traditional, crispy Dosai at home.
#
# This process is broken down into four main stages:
# 1.  **Soaking** the ingredients.
# 2.  **Grinding** to create the batter.
# 3.  **Fermenting** the batter (the most crucial step).
# 4.  **Cooking** the Dosai.
#
# ### **The Ultimate Dosai Procedure**
#
# This recipe yields a classic, crispy, and flavorful dosai.
#
# ---
#
# ### **Ingredients**
#
# The ratio of rice to dal is key. A common and reliable ratio is 3:1 or 4:1. We'll use 3:1 here.
#
# *   **Rice:** 3 cups (Use Idli Rice or any short-grain parboiled rice. Sona Masoori also works well).
# *   **Urad Dal:** 1 cup (Skinned black gram lentil).
# *   **Fenugreek Seeds (Methi):** 1 teaspoon (This aids fermentation and adds a lovely aroma).
# *   **Chana Dal (Bengal Gram):** 2 tablespoons (Optional, but gives a beautiful golden color and extra crispiness).
# ...
